# %%
# %load_ext autoreload
# %autoreload 2

# %%
from GmmHmm import GmmHmm
import numpy as np

hmm = GmmHmm(2, 2)
hmm.transition_probability = np.array([[0.5, 0.5],
                                       [0.3, 0.7]])
hmm.initial_states = np.array([0.375, 0.625])
log_lik, alpha, prob = hmm.forward( np.array([
    [0.8, 0.8, 0.2],
    [0.4, 0.4, 0.6]
])
)
alpha, np.e**log_lik, prob
# Out:
# [0.375 0.625]
# (array([[0.3   , 0.18  , 0.0258],
#         [0.25  , 0.13  , 0.1086]]),
#  0.041664000000000034,
#  0.13440000000000002)

# %%
# Out:
# (array([[0.075  , 0.0375 , 0.06705],
#         [0.5    , 0.31   , 0.0943 ]]),
#  0.05606912500000002)

# %%
emmision = np.array([[0.8, 0.2],
                                        [0.8, 0.2],
                                        [0.4, 0.6]])

# %%
emmision.T.shape
# Out:
# (2, 3)

# %%
np.e**np.log(10)
# Out:
# 10.000000000000002
