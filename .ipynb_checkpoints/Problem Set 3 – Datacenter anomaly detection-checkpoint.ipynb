# %% [markdown]
# # Datacenter anomaly detection

# %% [markdown]
# In this problem, you are going to build a model, which finds anomalies in the behavior of virtual machines in the datacenter.
#
# We have collected for you a number of logs on VMs (actually, the dataset is a real data from a real datacenter). The logs are CPU load and memory load (RAM) for every VM. Your goal is to build a system detecting abnormal behavior of the VMs so that the system administrator can notice them and pay attention.
#
# The data and Jupyter notebook file with some pre-defined code for you can be found in the folder datacenter.
#
# Take a look at <b>system-load.csv</b>. This is a raw data file, partially preprocessed for you. You can open in in any text editor or table editor such as Excel. CSV is one of the most popular data format files, you will often use in in your study and at work. It is worth to investigate how it looks in details.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from matplotlib.patches import Ellipse

# %%
# %matplotlib inline

# %% [markdown]
# ## Initialization

# %% [markdown]
# Log file with VM usage statistics.

# %%
input_filename = "system-load.csv"

# %% [markdown]
# Number of Gaussians.

# %%
num_gaussians = 3

# %% [markdown]
# Convergence threshold.

# %%
convergence_eps = 0.01

# %% [markdown]
# Random seed.

# %%
random_seed = 42

# %% [markdown]
# ## Loading the data

# %%
df_load = pd.read_csv(input_filename)

# %%
X = df_load.values

# %% [markdown]
# Normalizing the data to the range [0..1].

# %%
X = (X - np.min(X, axis=0)) / (np.max(X, axis=0) - np.min(X, axis=0))

# %%
m, n = X.shape

# %%
plt.figure(figsize=(6, 6))
plt.plot(X.T[0], X.T[1], "o", c="#144C59", alpha=0.5, markersize=3)

plt.xlabel("CPU usage")
plt.ylabel("RAM usage")
plt.show()

# %% [markdown]
# ## Training misture of Gaussians

# %%
np.random.seed(random_seed)

# %% [markdown]
# Initializing Gaussians at random data points.

# %%
means = X[np.random.choice(m, size=num_gaussians, replace=False)]

# %%
covariances = np.ones((num_gaussians, n, n)) * np.identity(n)

# %% [markdown]
# Initializing source probability for every Gaussian.

# %%
phis = np.ones(num_gaussians) / num_gaussians

# %% [markdown]
# Initializing correspondence probability matrix for every point.

# %%
W = np.zeros((num_gaussians, m))

# %% [markdown]
# Implement multivariate Gaussian PDF.

# %%
def multivariate_gaussian_pdf(X, mu, sigma):
    # =============== TODO: Your code here ===============
    # Compute the probability density function for the multivariate normal distribution.
    # NOTE: this function should also work when X is a 2D matrix (m x n).
    constant = np.sqrt((2*np.pi)**X.shape[-1] * np.linalg.det(sigma))
    density_result = np.zeros(X.shape[0])
    sigma_inv = np.linalg.inv(sigma)
    for i in range(len(X)):
        density_result[i] = np.exp(((X[i] - mu).T @ sigma_inv @ (X[i] - mu))/(-2))
    return density_result / constant

# %% [markdown]
# Implement E step of EM algorithm.

# %%
def e_step(X, means, covariances, phis):
    num_gaussians = len(means)
    W = np.zeros((num_gaussians, len(X)))
    
    # =============== TODO: Your code here ===============
    # Compute W for each Gaussian.
    
    # ====================================================
#     for i in range(len(X)):
    densities = np.array([multivariate_gaussian_pdf(X,means[k], covariances[k]) for k in range(num_gaussians)])
    
    for n in range(len(X)):
        phis_densities_sum = phis @ densities[:,n]
        W[:, n] = (phis*densities[:, n]) / phis_densities_sum
            
    return W

# %% [markdown]
# Implement M step of EM algorithm.

# %%
covariances.shape
# Out:
# (3, 2, 2)

# %%
def m_step(X, W):
    num_gaussians = len(W)
    m, n = X.shape
    
    phis = np.zeros(num_gaussians)
    means = np.zeros((num_gaussians, n))
    covariances = np.zeros((num_gaussians, n, n))
    
    # =============== TODO: Your code here ===============
    # Compute phi, mean, and covariance for each Gaussian.
    
    # ====================================================
    for k in range(num_gaussians):
        N_k = W[k].sum()
        means[k] = (X.T @ W[k]) / N_k
        for n in range(len(X)):
            X_minus_mean = X[n] - means[k]
            covariances[k] += W[k, n] * np.multiply.outer(X_minus_mean, X_minus_mean)
        covariances[k] /= N_k
        phis[k] = N_k / len(X)
        

    return phis, means, covariances

# %% [markdown]
# **Run EM until convergence**

# %%
def gmm_log_likelihood(x, phis, means, covariances, num_gaussians):
    # =============== TODO: Your code here ===============
    # Compute log likelihood of the mixture of Gaussians.
    
    # ====================================================
    sm = 0
    densities = np.array([multivariate_gaussian_pdf(X,means[k], covariances[k]) for k in range(num_gaussians)])
    for i in range(len(X)):
        sm += np.log((phis * densities[:, i]).sum())
    return sm

# %%
W = np.zeros((num_gaussians, m))
phis = np.ones(num_gaussians) / num_gaussians
covariances = np.ones((num_gaussians, n, n)) * np.identity(n)
means = X[np.random.choice(m, size=num_gaussians, replace=False)]
log_likelihoods = []
max_em_iterations = 200
for iteration in range(max_em_iterations):
    # E-step.
    W = e_step(X, means, covariances, phis)
#     print(covariances)
#     break
    # Compute log-likelihood.
    log_likelihood = gmm_log_likelihood(X, phis, means, covariances, num_gaussians)
    log_likelihoods.append(log_likelihood)
    print(log_likelihood)
    print("Iteration: {0:3d}    Log-likelihood: {1:10.4f}".format(iteration, log_likelihood))

    # M-step.
    phis, means, covariances = m_step(X, W)
    
    # Check log-likelihood for convergence.
    if len(log_likelihoods) > 2 and np.abs(log_likelihoods[-1] - log_likelihoods[-2]) < convergence_eps:
        print("EM has converged. Stopping early.")
        break
# Out:
# -1798.8001437343191
# Iteration:   0    Log-likelihood: -1798.8001
# 1124.9863111737122
# Iteration:   1    Log-likelihood:  1124.9863
# 1136.6044598812148
# Iteration:   2    Log-likelihood:  1136.6045
# 1173.2717652738222
# Iteration:   3    Log-likelihood:  1173.2718
# 1225.4080647881767
# Iteration:   4    Log-likelihood:  1225.4081
# 1261.2203819065273
# Iteration:   5    Log-likelihood:  1261.2204
# 1278.1961331955051
# Iteration:   6    Log-likelihood:  1278.1961
# 1286.9721903675918
# Iteration:   7    Log-likelihood:  1286.9722
# 1293.1055902181354
# Iteration:   8    Log-likelihood:  1293.1056
# 1298.4912774223972
# Iteration:   9    Log-likelihood:  1298.4913
# 1303.4662937872552
# Iteration:  10    Log-likelihood:  1303.4663
# 1307.695650850931
# Iteration:  11    Log-likelihood:  1307.6957
# 1310.828920808082
# Iteration:  12    Log-likelihood:  1310.8289
# 1312.8970684123424
# Iteration:  13    Log-likelihood:  1312.8971
# 1314.209264353204
# Iteration:  14    Log-likelihood:  1314.2093
# 1315.077445676272
# Iteration:  15    Log-likelihood:  1315.0774
# 1315.7037068337193
# Iteration:  16    Log-likelihood:  1315.7037
# 1316.1974969951827
# Iteration:  17    Log-likelihood:  1316.1975
# 1316.6150183968111
# Iteration:  18    Log-likelihood:  1316.6150
# 1316.9852586576126
# Iteration:  19    Log-likelihood:  1316.9853
# 1317.3235578715685
# Iteration:  20    Log-likelihood:  1317.3236
# 1317.6383197673538
# Iteration:  21    Log-likelihood:  1317.6383
# 1317.9343498234737
# Iteration:  22    Log-likelihood:  1317.9343
# 1318.2145436072142
# Iteration:  23    Log-likelihood:  1318.2145
# 1318.4807533738226
# Iteration:  24    Log-likelihood:  1318.4808
# 1318.734238482231
# Iteration:  25    Log-likelihood:  1318.7342
# 1318.9759027537991
# Iteration:  26    Log-likelihood:  1318.9759
# 1319.206422227518
# Iteration:  27    Log-likelihood:  1319.2064
# 1319.4263166643575
# Iteration:  28    Log-likelihood:  1319.4263
# 1319.6359925418237
# Iteration:  29    Log-likelihood:  1319.6360
# 1319.8357719289343
# Iteration:  30    Log-likelihood:  1319.8358
# 1320.0259145014165
# Iteration:  31    Log-likelihood:  1320.0259
# 1320.2066360703786
# Iteration:  32    Log-likelihood:  1320.2066
# 1320.378124892087
# Iteration:  33    Log-likelihood:  1320.3781
# 1320.5405559645394
# Iteration:  34    Log-likelihood:  1320.5406
# 1320.6941030923165
# Iteration:  35    Log-likelihood:  1320.6941
# 1320.8389484539557
# Iteration:  36    Log-likelihood:  1320.8389
# 1320.9752895502395
# Iteration:  37    Log-likelihood:  1320.9753
# 1321.1033436146788
# Iteration:  38    Log-likelihood:  1321.1033
# 1321.2233497464865
# Iteration:  39    Log-likelihood:  1321.2233
# 1321.3355691422582
# Iteration:  40    Log-likelihood:  1321.3356
# 1321.4402838493586
# Iteration:  41    Log-likelihood:  1321.4403
# 1321.5377944542163
# Iteration:  42    Log-likelihood:  1321.5378
# 1321.6284170729243
# Iteration:  43    Log-likelihood:  1321.6284
# 1321.7124799484518
# Iteration:  44    Log-likelihood:  1321.7125
# 1321.790319893188
# Iteration:  45    Log-likelihood:  1321.7903
# 1321.862278755405
# Iteration:  46    Log-likelihood:  1321.8623
# 1321.928700038019
# Iteration:  47    Log-likelihood:  1321.9287
# 1321.9899257580228
# Iteration:  48    Log-likelihood:  1321.9899
# 1322.0462936039164
# Iteration:  49    Log-likelihood:  1322.0463
# 1322.0981344253057
# Iteration:  50    Log-likelihood:  1322.0981
# 1322.1457700708272
# Iteration:  51    Log-likelihood:  1322.1458
# 1322.1895115773839
# Iteration:  52    Log-likelihood:  1322.1895
# 1322.2296577030838
# Iteration:  53    Log-likelihood:  1322.2297
# 1322.2664937887466
# Iteration:  54    Log-likelihood:  1322.2665
# 1322.3002909266472
# Iteration:  55    Log-likelihood:  1322.3003
# 1322.3313054112743
# Iteration:  56    Log-likelihood:  1322.3313
# 1322.3597784439032
# Iteration:  57    Log-likelihood:  1322.3598
# 1322.3859360612717
# Iteration:  58    Log-likelihood:  1322.3859
# 1322.4099892583743
# Iteration:  59    Log-likelihood:  1322.4100
# 1322.4321342754868
# Iteration:  60    Log-likelihood:  1322.4321
# 1322.4525530211206
# Iteration:  61    Log-likelihood:  1322.4526
# 1322.4714136039916
# Iteration:  62    Log-likelihood:  1322.4714
# 1322.488870949482
# Iteration:  63    Log-likelihood:  1322.4889
# 1322.505067478362
# Iteration:  64    Log-likelihood:  1322.5051
# 1322.520133828144
# Iteration:  65    Log-likelihood:  1322.5201
# 1322.5341896000139
# Iteration:  66    Log-likelihood:  1322.5342
# 1322.5473441169047
# Iteration:  67    Log-likelihood:  1322.5473
# 1322.5596971805408
# Iteration:  68    Log-likelihood:  1322.5597
# 1322.5713398177636
# Iteration:  69    Log-likelihood:  1322.5713
# 1322.5823550083323
# Iteration:  70    Log-likelihood:  1322.5824
# 1322.5928183884255
# Iteration:  71    Log-likelihood:  1322.5928
# 1322.6027989255651
# Iteration:  72    Log-likelihood:  1322.6028
# EM has converged. Stopping early.

# %%
plt.figure(figsize=(12, 6))
plt.plot(log_likelihoods)

plt.xlabel("# Iteration")
plt.ylabel("Log-likelihood")
plt.title("Learning Progress")

plt.show()

# %% [markdown]
# ## Visualizing the results

# %%
def plot_ellipse(pos, cov, nstd=2, ax=None, **kwargs):
    def eigsorted(cov):
        vals, vecs = np.linalg.eigh(cov)
        order = vals.argsort()[::-1]
        return vals[order], vecs[:,order]

    if ax is None:
        ax = plt.gca()

    vals, vecs = eigsorted(cov)
    theta = np.degrees(np.arctan2(*vecs[:,0][::-1]))

    width, height = 2 * nstd * np.sqrt(abs(vals))
    ellip = Ellipse(xy=pos, width=width, height=height, angle=theta, **kwargs)

    ax.add_artist(ellip)
    return ellip

# %%
def plot_gaussians(X, means, covs, ax=None):
    n = len(means)
    colors = ["#1F77B4", "#2CA02C", "#FFBB78", "#4C529B"]
    
    plt.cla()
    plt.plot(X.T[0], X.T[1], "o", c="#144C59", alpha=0.5, markersize=3)
    
    for k in range(num_gaussians):
        plot_ellipse(means[k], covs[k], ax=ax, alpha=0.4, color=colors[k % len(colors)])

# %%
plot_gaussians(X, means, covariances)

plt.xlabel("CPU usage")
plt.ylabel("RAM usage")
plt.show()
